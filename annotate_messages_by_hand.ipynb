# %%
import pymongo
import csv
import json
from random import randint
from bson.objectid import ObjectId
from nltk import agreement
import datetime
from json import JSONEncoder

# %% [markdown]
# # 1. Select messages based on classifiers
# In this part we select messages that we will then label by hand. We select the messages in the following way:
#
# * In total we select 700 messages
# * There should not be any duplicates
# * For each of the seven classifiers (Perpective API, Germeval 18, Germeval 19, Germeval 1819, Hasoc 2020, Hasoc 1920, Covid 2021) we select 50 OFFENSIVE messages and 50 NEUTRAL messages

# %%
client = pymongo.MongoClient("mongodb://localhost:27017/")

# %%
messages_collection = client.telegram.messages


def get_german_messages():
    query = {"language" : "de"}
    query_res = messages_collection.find(query, {"_id": 1, "text": 1, "link_preview": 1, "link_preview_title": 1,
                                                 "hate_germeval_18": 1, "hate_germeval_19": 1, 
                                                "hate_germeval_1819": 1, "toxicity_score_preprocessed": 1, "toxicity_score": 1,
                                                "hate_hasoc_2020": 1, "hate_hasoc_1920": 1, "hate_covid_2021": 1})
    messages = [msg for msg in query_res if msg['text'] is not None]
    return messages

# %%
messages = get_german_messages()
print(len(messages))
# Out:
# 5439691

# %% [markdown]
# As the different classifiers have different labels, we define a helper function that converts these different labels in OFFENSIVE and NEUTRAL.

# %%
OFFENSE = 1
NEUTRAL = 0

# %%
def get_label(msg, classifier):
    if classifier == "perspective_api":
        score = 0
        if "toxicity_score_preprocessed" in msg:
            score = msg['toxicity_score_preprocessed']
        else:
            score = msg['toxicity_score']
        return OFFENSE if score > 0.5 else NEUTRAL
    
    if classifier in ["hate_germeval_18", "hate_germeval_19", "hate_germeval_1819"]:
        return OFFENSE if msg[classifier]['label'] == 'OFFENSE' else NEUTRAL
    
    if classifier in ["hate_hasoc_2020", "hate_hasoc_1920"]:
        return OFFENSE if msg[classifier]['label'] == 'HOF' else NEUTRAL
    
    if classifier == "hate_covid_2021":
        return OFFENSE if msg[classifier]['label'] == 'abusive' else NEUTRAL

# %% [markdown]
# If there is a link preview and/or a link preview title, then we want to append those at the end of the message. To do this we define another helper function that appends the link preview (title) if available.

# %%
def get_full_text(msg):
    text = msg['text']
    if msg['link_preview_title'] is not None:
        text += '\n+++ LINK PREVIEW TITLE ++++++++++++++++++++++++++\n' + msg['link_preview_title']
    if msg['link_preview'] is not None:
        text += '\n+++ LINK PREVIEW ++++++++++++++++++++++++++\n' + msg['link_preview'] + '\n++++++++++++++++++++++++++++++++++++++++++++++++++++'
    return text

# %% [markdown]
# Now we select for each classifer 50 offensive and 50 neutral messages

# %%
classifiers = ["perspective_api", "hate_germeval_18", "hate_germeval_19", "hate_germeval_1819", "hate_hasoc_2020",
               "hate_hasoc_1920", "hate_covid_2021"]
selected_messages = set()

# %%
for classifier in classifiers:
    count_offense = 0
    count_neutral = 0
    while count_offense < 50 or count_neutral < 50:
        random_number = randint(0, len(messages) - 1)
        msg = messages[random_number]
        label = get_label(msg, classifier)
        if label == OFFENSE and count_offense < 50:
            text = get_full_text(msg)
            if text not in selected_messages:
                selected_messages.add((text, msg['_id']))
                count_offense += 1
        elif label == NEUTRAL and count_neutral < 50:
            text = get_full_text(msg)
            if text not in selected_messages:
                selected_messages.add((text, msg['_id']))
                count_neutral += 1

# %% [markdown]
# All the selected messages are saved in a separate text file. The name of the text file is the id of the message, such that we can later query the corresponding message again.

# %%
for msg, _id in selected_messages:
    f = open("messages_for_annotation/" + str(_id) + ".txt", "w+")
    f.write(msg)
    f.close()

# %% [markdown]
# # 2. Select messages according to topic model
# Additionally, we select 450 messages according to a topic model. We did not do this by ourself but have received a list of message ids that  were selected. Now we have to read that list, select the corresponding messages and save them.

# %%
with open('ID_collection_topic_model.csv', newline='') as f:
    reader = csv.reader(f)
    ids = list(reader)[1:]

print(ids)
# Out:
# [['605356bdfb9ea2ab4ac179aa'], ['60551b84210cd4ce6eb7ef3f'], ['605614484a7c0d0e24d9fb3c'], ['6054f325077685f1acb7d574'], ['6057cf17732b5380b43bc614'], ['6051ff616216bf3ffd44fda1'], ['605201fce0a38c0d01451e64'], ['6054f325077685f1acb7d589'], ['60534ed22e37b25760c11a4e'], ['605201b85c9a117ec7451a9b'], ['6051ff1d6216bf3ffd44fa41'], ['605205493e09b72d0a45445e'], ['605201dc7fbae3865545234a'], ['6055eec4f7099c2a96d9fa67'], ['605940615d6e5dfe12366588'], ['60521a50e22eda1ba8454f6e'], ['60595738fa0b4206ba366ea2'], ['605209fd207466b93f456e9a'], ['6059efed35bdf11df0366ba8'], ['6057d903fe5b029d853bcbee'], ['605201227fbae386554514d1'], ['60538610ed2127b15fc10322'], ['6055e050f6bbcd7175da20de'], ['60563d43c6a1cc1c7cd9ea24'], ['60534eff2e37b25760c11c30'], ['60522f1d97d4fc578a452ffc'], ['605770b143cddce45a60d396'], ['6059ff158f0c73b185366d21'], ['60552ce03df9ed0b73b8443c'], ['60537bbf06a5ab4d73c0fe76'], ['605208a5207466b93f455a98'], ['605527cdea54dee495b7f024'], ['6054d5939c8a27168dc336d9'], ['60550b0f7d6d343985b7dcb0'], ['605201dc7fbae386554523b1'], ['6055e922f6bbcd7175da8fec'], ['60580121cfc620678c3be1fc'], ['605202ec3e09b72d0a452455'], ['605246740b922332c72f8eb8'], ['605529443df9ed0b73b80cc6'], ['60520493207466b93f452c9c'], ['605203047fbae38655453916'], ['6059e376e01bd1b8fc3660e7'], ['6051ff1d6216bf3ffd44fade'], ['6055dff15949a7a7a5da19bf'], ['6059efed35bdf11df0366c60'], ['605744f71d63cbfd7cc928c5'], ['60586633823fd4bda13661dc'], ['6057b43f022cd516a83bc51f'], ['60552abe3df9ed0b73b8231a'], ['6055ba29f5cc58ef03d9f24d'], ['60575a296626ee0bd9c91fd3'], ['60579c5eec4bb7b64260c99e'], ['6055ec73fd59090bbcd9e954'], ['605632f5296799fe8bd9ee20'], ['6057931a3aa3ffdf3060d005'], ['60538610ed2127b15fc103c1'], ['60521d1d4578b9507844fd09'], ['60534c2d15b1562175c0f047'], ['6055efeb58052be80eda15a3'], ['605204aa7fbae38655455753'], ['60550a5a378eb0aac3b7dd58'], ['60560ea77a8b45f6ecd9f1aa'], ['6052304c97d4fc578a454176'], ['60521d55d2a3d12100450224'], ['60534e352e37b25760c11096'], ['6051ff9a207466b93f44fcc4'], ['6051fefe6216bf3ffd44f92e'], ['60537e19435ead3013c1221d'], ['60560ebc24a91ec648d9fb57'], ['605201227fbae386554515b3'], ['6055dc32f6bbcd7175d9f180'], ['6056729ffc600280af2cf9a0'], ['6051fefe6216bf3ffd44f951'], ['605202aa7fbae3865545337f'], ['6051ff616216bf3ffd44fedb'], ['6054da7a1b8a6f66b7b7d219'], ['60522aebc7a95c51dc44fc38'], ['6059a03e015496bbbf3664c2'], ['605711d91debb4b6d3737f1b'], ['6055ee4ec8cc8ff0e7d9fdce'], ['60550bbb926dc769f3b7f337'], ['60584d9d772ed5cf303bca22'], ['6054f6fd333cc54f42b80fba'], ['605a0663f260c74cfb36633e'], ['605201227fbae386554515ee'], ['605616ea4a7c0d0e24da2111'], ['60565d71e441221d6dfb5038'], ['605382519a15d35bc1c14d97'], ['6052465aece88e060f2f8d7a'], ['6053878aed2127b15fc11a68'], ['60538723ed2127b15fc114f5'], ['605227edd2a3d12100458fb2'], ['6057cf6cdea95ae6f83bca3a'], ['6058c31a72037d40df366020'], ['6055edd6c8cc8ff0e7d9f7d3'], ['6055fb3b67f8f21506d9ea24'], ['60534216ec6e11946ec0ebc0'], ['605354bbfb9ea2ab4ac15e27'], ['6057c227c792da6ba43bd6f4'], ['6053375eda0f4133b8c11607'], ['6051ff3e6216bf3ffd44fb6b'], ['6053369cda0f4133b8c10ab6'], ['60534db4d10d3cd90ec0f8eb'], ['6054f98e53ece65ce1b82463'], ['605a10e525fa9d639c3664ec'], ['60598afef3a217f428368719'], ['6058c3cf03cb1880d93666b1'], ['60520258e0a38c0d01452625'], ['60534db4d10d3cd90ec0f903'], ['6055195fc105599738b7d136'], ['6052059d207466b93f453657'], ['60520113207466b93f450c4b'], ['6052064658b5eaca03454605'], ['605529443df9ed0b73b80de9'], ['605204f67fbae38655455d9b'], ['6056234342fdd4f210d9ea9b'], ['6051ff9a207466b93f44fddd'], ['605219bde22eda1ba84547c8'], ['605201501da6a54c2d45166e'], ['605202187fbae3865545281f'], ['60579bee32c548b20f60c577'], ['605263c90e839826179566f0'], ['605203867fbae38655454381'], ['6055bb27a5c54cb93ada0225'], ['605745d21d63cbfd7cc935eb'], ['605817ed02a63e8c233be148'], ['6054f37c077685f1acb7d9d2'], ['605200be92c67d3aac450e04'], ['605385f0ed2127b15fc10285'], ['60596652e89cd5477f36608f'], ['6057e108fe50ae3b2d3bc5c9'], ['6056111124a91ec648da27cb'], ['6058796 ...

# %%
selected_messages = []
for l in ids:
    _id = l[0]
    query = {'_id': ObjectId(_id)}
    msg = messages_collection.find_one(query, {"_id": 1, "text": 1, "link_preview": 1, "link_preview_title": 1})
    if msg['text'] is not None:
        selected_messages.append((get_full_text(msg), msg['_id']))

# %%
print(len(selected_messages))
# Out:
# 449

# %%
for msg, _id in selected_messages:
    f = open("sampled_messages_topic_model/" + str(_id) + ".txt", "w+")
    f.write(msg)
    f.close()

# %% [markdown]
# # 3. Analyze results of the sample round
# We labeled 50 messages is a sample round, to see whether the inter-rater-reliability is reasonably good. In this part we will analyze the results of this sample round and calculate the Krippendorff alpha.

# %%
f = open('sample_round_results.json',)
data = json.load(f)
print(len(data))
# Out:
# 50

# %%
print(data)
# Out:
# [{'content': 'https://cloud.kili-technology.com/api/label/v2/files?id=933825df-fc22-4e1a-8966-fe1e61355703', 'externalId': '605a06cede26ef3a9b36650e.txt', 'id': 'ckql4dq8301kk0lrqf3i03go9', 'jsonMetadata': {}, 'labels': [{'author': {'email': 'maximilian.wich@tum.de', 'id': 'ckql085ur05cc0kpm2e3f0mk1', 'name': 'maximilian.wich@tum.de'}, 'createdAt': '2021-07-01T16:26:33.474Z', 'isLatestLabelForUser': True, 'jsonResponse': 'NEUTRAL', 'labelType': 'DEFAULT', 'modelName': None, 'skipped': False}, {'author': {'email': 'jeremias.bohn@tum.de', 'id': 'ckql0eeh0000r0kqh59l9h8vw', 'name': 'jeremias.bohn@tum.de'}, 'createdAt': '2021-07-01T16:34:05.004Z', 'isLatestLabelForUser': True, 'jsonResponse': 'NEUTRAL', 'labelType': 'DEFAULT', 'modelName': None, 'skipped': False}, {'author': {'email': 'ge46rev@mytum.de', 'id': 'ckql0dvoi00280kqg68v67voe', 'name': 'ge46rev@mytum.de'}, 'createdAt': '2021-07-01T19:24:53.437Z', 'isLatestLabelForUser': True, 'jsonResponse': 'NEUTRAL', 'labelType': 'DEFAULT', 'modelName': None, 'skipped': False}, {'author': {'email': 'daniel.bartmann.fs@googlemail.com', 'id': 'ckqjnxpqy00he0ku30wexbe5l', 'name': 'daniel.bartmann.fs@googlemail.com'}, 'createdAt': '2021-07-02T08:22:09.432Z', 'isLatestLabelForUser': True, 'jsonResponse': 'NEUTRAL', 'labelType': 'DEFAULT', 'modelName': None, 'skipped': False}, {'author': {'email': 'kim.ouan@tum.de', 'id': 'ckql0er7g001x0kv4foqd2smd', 'name': 'kim.ouan@tum.de'}, 'createdAt': '2021-07-02T20:01:20.685Z', 'isLatestLabelForUser': True, 'jsonResponse': 'NEUTRAL', 'labelType': 'DEFAULT', 'modelName': None, 'skipped': False}]}, {'content': 'https://cloud.kili-technology.com/api/label/v2/files?id=9c3ecc51-7219-4125-b0ab-00780f408ab0', 'externalId': '605a06932095b610ad3663b8.txt', 'id': 'ckql4dq8401kl0lrq7jfk0bpy', 'jsonMetadata': {}, 'labels': [{'author': {'email': 'jeremias.bohn@tum.de', 'id': 'ckql0eeh0000r0kqh59l9h8vw', 'name': 'jeremias.bohn@tum.de'}, 'createdAt': '2021-07-01T16:34:05.917Z', 'isLatestLabelForUser': True, 'jsonResponse': 'NEUTRAL', 'labelType': 'DEFAULT', 'modelName': None, 'skipped': False}, {'author': {'email': 'ge46rev@mytum.de', 'id': 'ckql0dvoi00280kqg68v67voe', 'name': 'ge46rev@mytum.de'}, 'createdAt': '2021-07-01T19:25:05.641Z', 'isLatestLabelForUser': True, 'jsonResponse': 'NEUTRAL', 'labelType': 'DEFAULT', 'modelName': None, 'skipped': False}, {'author': {'email': 'daniel.bartmann.fs@googlemail.com', 'id': 'ckqjnxpqy00he0ku30wexbe5l', 'name': 'daniel.bartmann.fs@googlemail.com'}, 'createdAt': '2021-07-02T08:22:25.170Z', 'isLatestLabelForUser': True, 'jsonResponse': 'NEUTRAL', 'labelType': 'DEFAULT', 'modelName': None, 'skipped': False}, {'author': {'email': 'kim.ouan@tum.de', 'id': 'ckql0er7g001x0kv4foqd2smd', 'name': 'kim.ouan@tum.de'}, 'createdAt': '2021-07-02T20:01:42.699Z', 'isLatestLabelForUser': True, 'jsonResponse': 'NEUTRAL', 'labelType': 'DEFAULT', 'modelName': None, 'skipped': False}, {'author': {'email': 'maximilian.wich@tum.de', 'id': 'ckql085ur05cc0kpm2e3f0mk1', 'name': 'maximilian.wich@tum.de'}, 'createdAt': '2021-07-04T12:06:15.984Z', 'isLatestLabelForUser': True, 'jsonResponse': 'NEUTRAL', 'labelType': 'DEFAULT', 'modelName': None, 'skipped': False}]}, {'content': 'https://cloud.kili-technology.com/api/label/v2/files?id=db9c7a82-4076-433a-9a57-ec8fbc172eec', 'externalId': '605a3946608183fd83368b15.txt', 'id': 'ckql4dq8401km0lrqh2j49zcz', 'jsonMetadata': {}, 'labels': [{'author': {'email': 'jeremias.bohn@tum.de', 'id': 'ckql0eeh0000r0kqh59l9h8vw', 'name': 'jeremias.bohn@tum.de'}, 'createdAt': '2021-07-01T16:34:06.863Z', 'isLatestLabelForUser': True, 'jsonResponse': 'NEUTRAL', 'labelType': 'DEFAULT', 'modelName': None, 'skipped': False}, {'author': {'email': 'ge46rev@mytum.de', 'id': 'ckql0dvoi00280kqg68v67voe', 'name': 'ge46rev@mytum.de'}, 'createdAt': '2021-07-01T19:25:12.836Z', 'isLatestLabelForUser': True, 'jsonResponse': 'NEUTRAL', 'labelType': 'DEFAULT', 'modelName': None, 'skipped': False}, {'author': {'email': 'daniel.bartmann.fs@go ...

# %%
assignments = []
for entry in data:
    _id = entry['externalId'][0:-4]
    labels = entry['labels']
    for label_entry in labels:
        author_id = label_entry['author']['id']
        if label_entry['isLatestLabelForUser'] and not label_entry['skipped']:
            label = label_entry['jsonResponse']
            assignments.append((author_id, _id, label))

# %%
print(len(assignments))
# Out:
# 245

# %%
ratingtask = agreement.AnnotationTask(data=assignments)
print('Krippendorff\'s alpha:',ratingtask.alpha())
# Out:
# Krippendorff's alpha: 0.6315102040816327

# %% [markdown]
# # 4. Get gold labels from annotation results
# Now we will analyze the annotation results and set the gold labels for the selected messages. The gold label will be the label with the majority vote. If there is a tie, then the message will be relabeled in another labeling round.

# %%
neutral_label = 'NEUTRAL'
offensive_label = 'OFFENSIVE_ABUSIVE'

# %%
def save_label(msg_id, label):
    query = {'_id': ObjectId(msg_id)}
    new_value = {"$set": {"gold_label": label}}
    messages_collection.update_one(query, new_value)

# %%
def analyze_annotation_results(annotation_data):
    indifferent_messages = []
    for entry in annotation_data:
        _id = entry['externalId'][0:-4]
        labels = entry['labels']
        neutral_count = 0
        offensive_count = 0
        for label_entry in labels:
            if label_entry['isLatestLabelForUser'] and not label_entry['skipped']:
                label = label_entry['jsonResponse']
                if label == neutral_label:
                    neutral_count += 1
                elif label == offensive_label:
                    offensive_count += 1
        if neutral_count > offensive_count:
            save_label(_id, neutral_label)
        elif offensive_count > neutral_count:
            save_label(_id, offensive_label)
        else:
            indifferent_messages.append(_id)
    return indifferent_messages

# %% [markdown]
# First we will look at the 50 messages from the sample round.

# %%
f = open('sample_round_results.json',)
data = json.load(f)
print(len(data))
# Out:
# 50

# %%
indifferent_messages = analyze_annotation_results(data)
print(len(indifferent_messages))
# Out:
# 0

# %% [markdown]
# There is no tie, so we do not need to relabel any message from the sample roud.
# Next we analyze the 1099 messages from the main round.

# %%
f = open('annotation_results.json',)
data = json.load(f)
print(len(data))
# Out:
# 1099

# %%
indifferent_messages = analyze_annotation_results(data)
print(len(indifferent_messages))
# Out:
# 126

# %% [markdown]
# We have in total 126 messages with a tie. These messages get labeled in a third round.

# %%
for _id in indifferent_messages:
    query = {'_id': ObjectId(_id)}
    msg = messages_collection.find_one(query, {"_id": 1, "text": 1, "link_preview": 1, "link_preview_title": 1})
    f = open("third_annotation_round/" + str(_id) + ".txt", "w+")
    if msg['text'] is not None:
        msg = get_full_text(msg)
    else:
        continue
    f.write(msg)
    f.close()

# %% [markdown]
# Let us analyze the results of the third annotation round

# %%
f = open('third_round_results.json',)
data = json.load(f)
print(len(data))
# Out:
# 126

# %%
indifferent_messages = analyze_annotation_results(data)
print(len(indifferent_messages))
# Out:
# 8

# %% [markdown]
# Let's have a closer look at thiose eight messages...

# %%
for _id in indifferent_messages:
    query = {'_id': ObjectId(_id)}
    msg = messages_collection.find_one(query, {"_id": 1, "text": 1, "link_preview": 1, "link_preview_title": 1})
    f = open("third_annotation_round/" + str(_id) + ".txt", "w+")
    if msg['text'] is not None:
        msg = get_full_text(msg)
        print(_id + '\n' + msg + '\n\n\n')
# Out:
# 60535dbb1c2b21aba4c0ea0d
# Zu diesem Video folgende Überlegungen:
# 1. In den Herkunftsländern der Migranten ist es sicherlich wärmer.
# 2. Was hat man eigentlich zu fordern, wenn man illegal in ein Land eindringt?
# Es wird immer so getan, als würden diese Menschen ungeheurem Leid ausgesetzt sein. Niemand hat sie gezwungen, ihre Heimat zu verlassen und illegal in andere Länder einzufallen.
# Mehr unter:
# t.me/nachrichtenportal
#
#
#
# 605613debd7aaf419bd9f091
# http://www.guidograndt.de/2020/09/10/kollegenbeitrag-riesen-zoff-um-querdenker-demo-in-wien-dem-zerreissen-einer-paedo-fahne-eine-richtigstellung-mit-fotos-videos/?fbclid=IwAR2MrG6jKm_ghx_bcjomKm47BO0hGLfRhoJTT1TjkjaqfHnL_5H-tqXR1Ac
# +++ LINK PREVIEW TITLE ++++++++++++++++++++++++++
# KOLLEGENBEITRAG: „Riesen-Zoff um Querdenker-Demo in Wien & dem Zerreißen einer Pädo-Fahne!“ – Eine Richtigstellung! (Mit Fotos…
# +++ LINK PREVIEW ++++++++++++++++++++++++++
# EIN KOLLEGENBEITRAG VON MANUEL C. MITTAS (Recherchenetzwerk Satanismus & rituelle Gewalt) Schauen Sie selbst was aus der Aktion mit der Regenbogenfahne von der Mainstreampresse konstruiert wurd…
# ++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
#
# 605730e0d81900375dc99873
# http://www.tagesschau.de/ausland/parkland-schuelerproteste-101.html
# +++ LINK PREVIEW TITLE ++++++++++++++++++++++++++
# Wendepunkt im Waffenstreit?
# +++ LINK PREVIEW ++++++++++++++++++++++++++
# Vor einem Jahr erschoss ein 19-Jähriger an einer Schule in Parkland 17 Menschen. Das Attentat löste Proteste gegen das Waffenrecht aus. Mit Erfolg: Vielerorts wurden die Waffengesetze verschärft. Von Sebastian Schreiber.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
#
# 6052025f92c67d3aac451d9c
# http://www.pi-news.net/2020/11/berlin-ex-moslem-bestaetigt-islam-aufklaerung-der-bpe/
# +++ LINK PREVIEW TITLE ++++++++++++++++++++++++++
# Berlin: Ex-Moslem bestätigt Islam-Aufklärung der BPE | PI-NEWS
#
#
#
# 6054916d92c52865064d6a33
# http://www.pi-news.net/2019/08/deutsche-opfer-fremde-taeter-zahlen-und-fakten/
# +++ LINK PREVIEW TITLE ++++++++++++++++++++++++++
# Deutsche Opfer, fremde Täter - Zahlen und Fakten
# +++ LINK PREVIEW ++++++++++++++++++++++++++
# Macheten- und Samurai-Schwertangriffe wie in Sydney, London, Innsbruck, Stuttgart und Gleisschubser wie in Frankfurt sind
# ++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#
#
# 60521862e22eda1ba8453b2c
# 🇺🇸
#
# Q-DROP 4015
# 💧
# - ÜBERSETZUNG
# 👆
# Adam Schiff, Leiter des Geheimdienst-Ausschusses des Repräsentantenhauses, fordert Google-YouTube-Twitter auf, ihre "autoritative" Zensur und ihr Schweigen zu verstärken
# Am Donnerstag schickte der Abgeordnete Adam Schiff, der unehrlichste und zwanghafteste Lügner im Kongress, einen Brief an die CEOs von Google, YouTube und Twitter, um sie zu drängen, ihre "autoritativen" Befugnisse zu nutzen, um Stimmen während der Coronavirus-Pandemie zu zensieren und zum Schweigen zu bringen.
# Letzte Woche sagte der YouTube-CEO gegenüber CNN, das Unternehmen werde jeden zum Schweigen bringen, der von der offiziellen WHO-Politik abweicht.
# Google ist damit einverstanden.
# Tatsächlich ist das Unternehmen sehr stolz auf ihre Zensur.
# Erinnern Sie sich im November daran. Die Demokraten unterstützen dies und wollen MEHR Zensur und Schweigen.
# Schiff hat diese Briefe an Google, YouTube und Twitter geschickt.
# 👉
#
# qmap.pub
# #Q
#
# #Drop
#
# #Qdrop
# t.me/buergerinformative/8423
#
#
#
# 60538740ed2127b15fc115fd
# Antifa-Aufklärung: Terrorzellen, Auftraggeber, Verbindungen bis in den Bundestag
# #Video
# Totalitär - Faschistisch - Terrorgruppen Antifa mit deren Auftraggebern bis in die Autonomen Verbindungen hinunter․ Wenn Argumente fehlen kommt die Keule․ Linksextreme Plattformen verbreiten Hass und Hetze, welche dann autonom umgesetzt werden
# ․
#
#
#
# 605770263bb6af174c60c6bc
# Diktatur und Faschismus! Die EU zeigt ihre hässliche Fratze: Corona wird zum Erpressungsversuch missbraucht!
#  Wehe dem, der sich gegen die Bürokraten in Brüssel auflehnt.  Der bekommt die ganze Härte der selbstherrlichen Diktatoren zu spüren. Besonders widerlich wird es, wenn diese dann eine „Seuche“ dazu missbrauchen, um ihre Vorstellung von „Rechtsstaatlichkeit“ durchzusetzen. Dann wird der Geldhahn einfach zugedreht und die renitenten Staaten ausgehungert!
# https://www.journalistenwatch.com/2020/12/04/die-eu-fratze/
# +++ LINK PREVIEW TITLE ++++++++++++++++++++++++++
# Die EU zeigt ihre hässliche Fratze: Corona wird zum Erpressungsversuch missbraucht › Jouwatch
# +++ LINK PREVIEW ++++++++++++++++++++++++++
# Wehe dem, der sich gegen die Bürokraten in Brüssel auflehnt.  Der bekommt die ganze Härte der selbstherrlichen Diktatoren zu spüren. ...
# ++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# We did discuss those eight message in group and decided on one label which we will set here manually.

# %%
save_label( '60535dbb1c2b21aba4c0ea0d', neutral_label)
save_label( '605613debd7aaf419bd9f091', neutral_label)
save_label( '605730e0d81900375dc99873', neutral_label)
save_label( '6052025f92c67d3aac451d9c', neutral_label)
save_label( '6054916d92c52865064d6a33', neutral_label)
save_label( '60521862e22eda1ba8453b2c', neutral_label)
save_label( '60538740ed2127b15fc115fd', neutral_label)

# %%
save_label( '605770263bb6af174c60c6bc', offensive_label)

# %% [markdown]
# # 5. Write Data to JSON Format
# In order to reuse the dataset that we have created, we store the 1149 messages with the gold label and the raw annotations in a file using the JSON format.

# %%
data = {}
data['messages'] = []

# %%
authors = {}

def prepare_for_json(annotation_data):
    messages = []
    for entry in annotation_data:
        _id = entry['externalId'][0:-4]
        query = {'_id': ObjectId(_id)}
        msg = messages_collection.find_one(query, {"_id": 1, "text": 1, "link_preview": 1, "link_preview_title": 1, 
                                                   "channel_name": 1, "datetime": 1, "post_id": 1, "gold_label": 1})
        msg['_id'] = _id
        msg['raw_annotations'] = {}
        neutral_count = 0
        offensive_count = 0
        labels = entry['labels']
        for label_entry in labels:
            if label_entry['isLatestLabelForUser'] and not label_entry['skipped']:
                label = label_entry['jsonResponse']
                if label == neutral_label:
                    neutral_count += 1
                elif label == offensive_label:
                    offensive_count += 1
                author_id = label_entry['author']['id']
                if author_id not in authors:
                    authors[author_id] = 'annotator_' + str(len(authors) + 1)
                msg['raw_annotations'][authors[author_id]] = label
        if neutral_count != offensive_count:
            messages.append(msg)
    return messages

# %% [markdown]
# First the 50 sample round messages

# %%
f = open('sample_round_results.json',)
sample_round_data = json.load(f)
print(len(sample_round_data))
# Out:
# 50

# %%
data['messages'].extend(prepare_for_json(sample_round_data))

# %%
print(len(data['messages']))
# Out:
# 50

# %% [markdown]
# Next the 1099 messages from the maiin annotation round

# %%
f = open('annotation_results.json',)
main_annotation_data = json.load(f)
print(len(main_annotation_data))
# Out:
# 1099

# %%
data['messages'].extend(prepare_for_json(main_annotation_data))
print(len(data['messages']))
# Out:
# 1023

# %% [markdown]
# Next the 126 messages that had to be relabeled in a third round due to a tie

# %%
f = open('third_round_results.json',)
third_round_data = json.load(f)
print(len(third_round_data))
# Out:
# 126

# %%
data['messages'].extend(prepare_for_json(third_round_data))
print(len(data['messages']))
# Out:
# 1141

# %% [markdown]
# Now we have to manually add the eight messages that we have discussed in person

# %%
ids = ['60535dbb1c2b21aba4c0ea0d', '605613debd7aaf419bd9f091', '605730e0d81900375dc99873', '6052025f92c67d3aac451d9c', 
      '6054916d92c52865064d6a33', '60521862e22eda1ba8453b2c', '60538740ed2127b15fc115fd', '605770263bb6af174c60c6bc']
daniel_bartmann_id = "ckqjnxpqy00he0ku30wexbe5l"
maximilian_wich_id = "ckql085ur05cc0kpm2e3f0mk1"

for _id in ids:
    query = {'_id': ObjectId(_id)}
    msg = messages_collection.find_one(query, {"_id": 1, "text": 1, "link_preview": 1, "link_preview_title": 1, 
                                                   "channel_name": 1, "datetime": 1, "post_id": 1, "gold_label": 1})
    msg['_id'] = _id
    
    msg['raw_annotations'] = {}    
    msg['raw_annotations'][authors[daniel_bartmann_id]] = msg['gold_label']
    msg['raw_annotations'][authors[maximilian_wich_id]] = msg['gold_label']
    data['messages'].append(msg)

print(len(data['messages']))
# Out:
# 1149

# %%
class DateTimeEncoder(JSONEncoder):
        def default(self, obj):
            if isinstance(obj, (datetime.date, datetime.datetime)):
                return obj.isoformat()

with open('annotated_dataset.txt', 'w') as outfile:
    json.dump(data, outfile, indent=4, cls=DateTimeEncoder)

# %% [markdown]
# # 6. Calculate Krippendorff's Alpha over whole Annotations

# %%
f = open('annotated_dataset.txt',)
data = json.load(f)
print(data)
# Out:
# {'messages': [{'_id': '605a06cede26ef3a9b36650e', 'channel_name': 'saraslightfight', 'post_id': 2750, 'datetime': '2021-01-23T09:57:02', 'text': 'Spektakuläres Urteil in Thüringen findet Weg in die Massenmedien\n❗️\n🦅\n#TEAMHEIMAT\n🇩🇪\n \nhttps://m.focus.de/politik/thueringer-urteil-bringt-regierung-in-erklaerungsnot-corona-hammer-gericht-nennt-lockdown-katastrophale-politische-fehlentscheidung_id_12899284.html', 'link_preview_title': 'Gerichtsentscheid in Thüringen: Spektakuläres Corona-Urteil: Richter nennt Lockdown "katastrophale Fehlentscheidung"', 'link_preview': 'Das Amtsgericht Weimar hat einen Mann freigesprochen, der im April 2020 gegen die Corona-Regeln verstoßen hatte. FOCUS Online liegt das hochbrisante Urteil vor. Es stuft das staatlich angeordnete allgemeine Kontaktverbot als verfassungswidrigern Tabubruch\xa0ein…', 'gold_label': 'NEUTRAL', 'raw_annotations': {'annotator_1': 'NEUTRAL', 'annotator_2': 'NEUTRAL', 'annotator_3': 'NEUTRAL', 'annotator_4': 'NEUTRAL', 'annotator_5': 'NEUTRAL'}}, {'_id': '605a06932095b610ad3663b8', 'channel_name': 'operationrubikon', 'post_id': 2404, 'datetime': '2021-01-31T19:15:38', 'text': '‼\n🇦🇹\n POLIZEI KAPITULIERT \nUND MARSCHIERT MIT DEM VOLK MIT \n🇦🇹\n‼\n \n🕊\n TEILEN \n🕊\n TEILEN \n🕊\nTEILEN \nso oft es geht.\n‼\n \n🇦🇹\n \n#FriedeFreiheitDemokratie\n \n🇦🇹\n \n@friede_freiheit_demokratie_at\n \n@friede_freiheit_demokratie_aut', 'link_preview_title': None, 'link_preview': None, 'gold_label': 'NEUTRAL', 'raw_annotations': {'annotator_2': 'NEUTRAL', 'annotator_3': 'NEUTRAL', 'annotator_4': 'NEUTRAL', 'annotator_5': 'NEUTRAL', 'annotator_1': 'NEUTRAL'}}, {'_id': '605a3946608183fd83368b15', 'channel_name': 'golem_de', 'post_id': 14425, 'datetime': '2019-09-13T08:39:14', 'text': 'Verschlüsselung: Firefox-Nightly soll altes TLS abschalten\n#Firefox\n \n#Browser\nDie großen Browser-Hersteller wollen im kommenden Frühjahr die alten TLS-Versionen 1․0 und 1․1 komplett deaktivieren․ Die Firefox-Entwickler werden das in ihrer Nightly-Version testen\n․', 'link_preview_title': None, 'link_preview': None, 'gold_label': 'NEUTRAL', 'raw_annotations': {'annotator_2': 'NEUTRAL', 'annotator_3': 'NEUTRAL', 'annotator_4': 'NEUTRAL', 'annotator_5': 'NEUTRAL', 'annotator_1': 'NEUTRAL'}}, {'_id': '6051ffd1207466b93f44fe7e', 'channel_name': 'attilahildmann', 'post_id': 45023, 'datetime': '2021-02-10T16:30:14', 'text': 'REICH DEN TÜRKEN IN DEUTSCHLAND UND DER WELT DIE HAND DEUTSCHER! ES SIND NICHT DEINE FEINDE! SIE HABEN BEWUSST DIE VÖLKER GESPALTEN UND GEGENEINANDER AUFGEHETZT! DIE TÜRKEN SIND DEIN FREUND ABER WIR ERWARTEN AUCH RESPEKT! WENN DU DENKST WIR SIND IRGENDWELCHE DUMMEN GASTARBEITER DANN TÄUSCHT DU DICH! WIR STEHEN AN DEINER SEITE ABER NUR MIT RESPEKT UND WENN DU DICH SELBST ERKENNST!', 'link_preview_title': None, 'link_preview': None, 'gold_label': 'NEUTRAL', 'raw_annotations': {'annotator_2': 'OFFENSIVE_ABUSIVE', 'annotator_3': 'NEUTRAL', 'annotator_4': 'OFFENSIVE_ABUSIVE', 'annotator_5': 'NEUTRAL', 'annotator_1': 'NEUTRAL'}}, {'_id': '6054ba28ee31b3eb59fd6b46', 'channel_name': 'systemgesund', 'post_id': 4111, 'datetime': '2021-02-19T07:16:59', 'text': '😱\n \nAngst ist ein schlechter Ratgeber, aber ein hervorragendes Machtinstrument \n🌍\nWill man als \n🌍\n Machthaber Bürger zu einem bestimmten Verhalten \n🔁\n bewegen, muss bewusst und gezielt Stimmung gemacht und \n😱\n Angst erzeugt werden. \nDadurch sind viele \n👫\nMenschen auf rationaler Ebene nicht mehr \n📲\n erreichbar und es ist kein einfacher Prozess, sich von dieser \n↔️\n Beeinflussung zu lösen.\n@SamuelEckert', 'link_preview_title': None, 'link_preview': None, 'gold_label': 'NEUTRAL', 'raw_annotations': {'annotator_2': 'NEUTRAL', 'annotator_3': 'NEUTRAL', 'annotator_4': 'NEUTRAL', 'annotator_5': 'NEUTRAL', 'annotator_1': 'NEUTRAL'}}, {'_id': '6055baf503a8cf1f93d9f913', 'channel_name': 'mh171702q2q', 'post_id': 42654, 'datetime': '2021-01-13T18:14:30', 'text': 'JUST IN - Menschenmenge mit dem Schild "Vertreibe alle Faschisten" vor dem ...

# %%
assignments = []
for msg in data['messages']:
    _id = msg['_id']
    for author, label in msg['raw_annotations'].items():
        assignments.append((author, _id, label))

# %%
ratingtask = agreement.AnnotationTask(data=assignments)
print('Krippendorff\'s alpha:', ratingtask.alpha())
# Out:
# Krippendorff's alpha: 0.7387221322705194
